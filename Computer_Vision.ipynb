# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
filepath = "./data/panda.jpg"

# %%
img = cv2.imread(filepath)

# %%
img
# Out:
# array([[[192, 184, 161],
#         [192, 179, 157],
#         [197, 176, 155],
#         ...,
#         [ 47,  83,  59],
#         [  0,  51,  23],
#         [ 61, 128,  99]],
#
#        [[197, 189, 166],
#         [197, 184, 162],
#         [201, 180, 159],
#         ...,
#         [124, 158, 134],
#         [ 16,  69,  42],
#         [ 52, 116,  87]],
#
#        [[203, 192, 172],
#         [202, 187, 168],
#         [207, 183, 165],
#         ...,
#         [172, 200, 177],
#         [ 67, 114,  88],
#         [ 65, 123,  95]],
#
#        ...,
#
#        [[ 14, 159, 121],
#         [  0, 145, 107],
#         [ 44, 203, 163],
#         ...,
#         [  0, 116,  85],
#         [  0, 109,  78],
#         [ 12, 145, 113]],
#
#        [[ 11, 139, 104],
#         [  2, 142, 105],
#         [ 21, 187, 146],
#         ...,
#         [  0, 113,  84],
#         [  0, 107,  77],
#         [ 17, 144, 113]],
#
#        [[  7, 120,  87],
#         [  9, 141, 105],
#         [  0, 168, 126],
#         ...,
#         [  0, 109,  80],
#         [  0, 104,  74],
#         [ 16, 140, 110]]], dtype=uint8)

# %%
img.shape
# Out:
# (159, 318, 3)

# %%
row = 0
col = 0

# %%
img[row][col]
# Out:
# array([192, 184, 161], dtype=uint8)

# %%
img[row,col]
# Out:
# array([192, 184, 161], dtype=uint8)

# %%
# cv2.imshow("Image",img)
# waitkey = cv2.waitKey(0)
# if waitkey == 27:
#     cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %%
gray_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
gray_img.shape
# Out:
# (159, 318)

# %%
# cv2.imshow("Image",gray_img)
# waitkey = cv2.waitKey(0)
# if waitkey == 27:
#     cv2.destroyAllWindows()

# %%
plt.imshow(gray_img,cmap="gray")

# %%
resized_img = cv2.resize(img,(50,50))

# %%
resized_img.shape
# Out:
# (50, 50, 3)

# %%
plt.imshow(resized_img)

# %%
## Array to image

# %%
R,G,B

# %%
[red,yellow,orange]
[blue,black,white]
[green,cyan,magenta]

# %%
np_array = np.array([[[255,0,0],[255,255,0],[255,128,0]],
                    [[0,0,255],[0,0,0],[255,255,255]],
                    [[0,255,0],[0,255,255],[255,0,255]]])

# %%
plt.imshow(np_array)
