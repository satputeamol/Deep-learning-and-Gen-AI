# %%
# !curl -X POST http://127.0.0.1:5000/pediction \
     -H "Content-Type: application/json" \
     -d '{"tweet": "Find out how you can protect yourself and loved ones from #coronavirus. ?"}'
# Out:
# {"final_pred":"Extremely Positive"}
